# %% [markdown]
# ### Read Relamn data -

# %%
import sys,os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 3 * matplotlib.rcParams['savefig.dpi']

# Read data matched with the blood samples - 
fi = os.getcwd()+'/PR_sample_data_matched_genus.csv'
dat = pd.read_csv(fi, header=[0, 1], index_col=[0, 1])

# Transpose so that bugs are columns and samples are rows and simplify comlumn naming - 
dat_tp=dat.transpose()
names=dat_tp.columns.get_level_values('tax_name')
dat_tp.columns=names

# Swap row levels so that we can easily slice by sample -
dat_tp=dat_tp.swaplevel('Sample', 'BodySite', axis=0)

# Remove all genus that are exclusive to blood, because metagenomic sequencing will be richer in this respect than 16s - 
dat_lessBlood=dat_tp[dat_tp.index.get_level_values('BodySite')!='Blood']
bug_sums=dat_lessBlood.sum(axis=0)
bug_sums_pruned=bug_sums[bug_sums>0]

# Re-slice the data to remove bugs exclusive to blood -
dat_tp=dat_tp[bug_sums_pruned.index]

# Normalized data for each sample - 
dat_tp_norm=dat_tp.div(dat_tp.sum(axis=1),axis=0)

print "There are %s samples with genus shared between blood / body sites, each of which measures %s bugs."%(dat_tp_norm.shape[0],dat_tp_norm.shape[1])
# Out:
# There are 268 samples with genus shared between blood / body sites, each of which measures 106 bugs.

# %% [markdown]
# ### Read HMP data -

# %%
# Get HMP data
fi = os.getcwd()+'/HMP_data_%s.csv'%'genus'
hmp_dat = pd.read_csv(fi, header=[0, 1], index_col=[0, 1])
hmp_dat_simple=hmp_dat.copy()
hmp_dat_simple.columns=hmp_dat_simple.columns.droplevel('specific_site')
hmp_dat_simple_tp=hmp_dat_simple.transpose()
hmp_dat_simple=hmp_dat_simple_tp.groupby(hmp_dat_simple_tp.index).apply(lambda x:np.mean(x,axis=0))
hmp_dat=hmp_dat_simple.transpose()
hmp_dat_norm=hmp_dat.div(hmp_dat.sum(axis=0),axis=1)
hmp_dat_norm.index=hmp_dat_norm.index.get_level_values('tax_name')
# Escherichia present in top 20 gut bugs in gut.
# Most abundant in gut relative to other sites. 
hmp_dat_norm.shape
# Out:
# (139, 5)

# %% [markdown]
# ### ICA -

# %% [markdown]
# Blood mixtures, $x$ ($M$ by $k$):
#
# $$ \begin{bmatrix} x_1 \\ ... \\ x_M \end{bmatrix}$$
#
# * $M$ blood mixtures.
# * Each has $k$ bugs measured.
#
# Mixing matrix, $A$ ($M$ by $n$):
#
# $$ \begin{bmatrix} a_{11} ... a_{1n} \\ ... \\  a_{M1}  ... a_{Mn} \end{bmatrix} $$
#
# * For each of $M$ blood mixtures, it provides a set of mixing terms.
# * Each mixing term is assocaited with one of the $N$ sources.
# * Each mixture in $X$ is thus a linear combination given by: $ x_j = a_{j1} s_1 + ... + a_{jn} s_n $
#
# Source matrix, $S$ ($n$ by $k$):
#
# $$ \begin{bmatrix} s_1 \\ ... \\ s_n \end{bmatrix} $$
#
# * These are the $n$ independent components of the model.
#
# The inner product of these terms can be written:
#
# * The common set of sources are combined as specified by the mixing matrix to give each.
# * Where each mixture, $x_j$, and source, $s_j$,  have the same dimentionality ($k$).
#
# Mixing:
#
# $$ \begin{bmatrix} x_1 \\ ... \\ x_M \end{bmatrix} =  \begin{bmatrix} a_{11} ... a_{1n} \\ ... \\  a_{M1}  ... a_{Mn} \end{bmatrix} \begin{bmatrix} s_1 \\ ... \\ s_n \end{bmatrix} $$
#
# $$ x = AS $$
#
# $$ S = A^{-1}x $$
#
# $$ W = A^{-1} $$
#
# $$ S = Wx $$
#
# Our goal is to find the unmixing matrix, $W$, that allows us to recover the source signals.

# %% [markdown]
# ### Simulate data -

# %%
# Slice by body site
stor=[]
for bodysite in set(dat_tp.index.get_level_values('BodySite')):
    # Slice data, givin n measurments x k bugs
    site_dat=dat_tp_norm[dat_tp_norm.index.get_level_values('BodySite')==bodysite]
    # Mean for each per bug
    site_mean=site_dat.mean(axis=0)
    # Store
    frac_bug_toagg=pd.DataFrame(site_mean,columns=[bodysite])
    stor=stor+[frac_bug_toagg]
bs_dat=pd.concat(stor,axis=1)
bs_dat.fillna(0,inplace=True)
bs_dat.head(5)
# Out:
#                    Stool    Saliva  CordBlood_Serum  Tooth_Gum  Back_of_ear_L  \
# tax_name
# Coprobacillus   0.001029  0.000000                0   0.000000       0.000000
# Capnocytophaga  0.000004  0.009623                0   0.014375       0.000000
# Collinsella     0.000592  0.000000                0   0.000000       0.000000
# Cupriavidus     0.000000  0.000000                0   0.000006       0.000000
# Granulicatella  0.000036  0.025379                0   0.032164       0.000547
#
#                    Blood  Vaginal_Swab
# tax_name
# Coprobacillus   0.000000      0.000000
# Capnocytophaga  0.000043      0.000002
# Collinsella     0.000000      0.000000
# Cupriavidus     0.243499      0.000000
# Granulicatella  0.000000      0.000006
#
# [5 rows x 7 columns]

# %%
import random

# Params
tissues=['Stool','Saliva','Vaginal_Swab','Back_of_ear_L']
dat_to_use=bs_dat[tissues]
num_example=60

# Store data
blood=pd.DataFrame(index=np.arange(num_example),columns=dat_to_use.index)
weights=pd.DataFrame(index=np.arange(num_example),columns=tissues)

# Iterate through bugs
for i in np.arange(num_example):    
    
    # Random weights
    
    weights.loc[i]=tissue_weight
    
    # Make data
    for bug in dat_to_use.index:
        blood.loc[i,bug]=np.sum(dat_to_use.loc[bug]*tissue_weight)

# %%
rand_nums=np.array([random.uniform(0,1) for x in range(4)])
tissue_weight=rand_nums/rand_nums.sum()
tissue_weight
# Out:
# array([ 0.42895057,  0.10777014,  0.03068602,  0.43259327])

# %%
def ICApreprocess(df):
    ''' Zero out the mean, and made stv one. '''
    # Normalize data by samples with zero mean 
    df_mean_norm=df.subtract(df.mean(axis=1),axis=0)
    # Normalize data by samples with unit variance 
    df_mean_var_norm=df_mean_norm.divide(df_mean_norm.std(axis=1),axis=0)
    return df_mean_var_norm

# Preprocess
X=ICApreprocess(blood)
X.head(3)
# Out:
# tax_name Coprobacillus Capnocytophaga Collinsella Cupriavidus Granulicatella  \
# 0           -0.1959212     -0.1381961  -0.1964173  -0.1970905    -0.03465794
# 1           -0.2498648     -0.2046568  -0.2512234  -0.2530673     -0.1214197
# 2           -0.3318509     -0.2070387  -0.3389732  -0.3486399     0.02808059
#
# tax_name Roseomonas Peptostreptococcus Ruminococcus Micrococcus  \
# 0        -0.1900084         -0.1923159   -0.1724255   -0.182891
# 1        -0.2491731         -0.2406072   -0.1852701    -0.24525
# 2         -0.345771         -0.3367247  0.005293636  -0.3428174
#
# tax_name Staphylococcus Streptococcus Enterococcus Lactococcus  \
# 0              2.410957       1.99723   -0.1970353  -0.1968986
# 1              1.206855      1.517708    -0.252435  -0.2525417
# 2             0.7125541      4.581935   -0.3483062  -0.3458844
#
# tax_name Catenibacterium Sphingomonas Aerococcus    Gemella  Atopobium  \
# 0              -0.194626   -0.1900084 -0.1964101 -0.1968184 -0.1609888
# 1             -0.2463171   -0.2491731 -0.2419162 -0.2515594  -0.222035
# 2              -0.313252    -0.345771 -0.3477139 -0.3480997 -0.2615099
#
# tax_name Clostridium  Finegoldia
# 0         -0.1892741  -0.1549955 ...
# 1         -0.2021858  0.09818057 ...
# 2         -0.2644708  0.03110891 ...
#
# [3 rows x 106 columns]

# %%
from pylab import *
from numpy import *
from scipy import stats
from sklearn.decomposition import FastICA

def runICA(X,ica_comp):
    ''' Run ICA with specified number of components''' 

    # ICA
    ica = FastICA(n_components=ica_comp)
    ica.fit(X.T)
    # Write computed source data to DF
    S_est_bugs = ica.transform(X.T)
    ica_sources=pd.DataFrame()
    for i, si in enumerate(S_est_bugs.T):
        ica_sources['Source_%s'%str(i+1)]=si    
    return (ica_sources,ica)

# Compute ICA
ica = FastICA(n_components=5)
ica.fit(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-7931c18b6cfa> in <module>()
#      19 # Compute ICA
#      20 ica = FastICA(n_components=5)
# ---> 21 ica.fit(X)
#
# /Users/lmartin/anaconda/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc in fit(self, X, y)
#     485         self
#     486         """
# --> 487         self._fit(X, compute_sources=True)  # will become False in 0.16
#     488         return self
#     489
#
# /Users/lmartin/anaconda/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc in _fit(self, X, compute_sources)
#     441             max_iter=self.max_iter, tol=self.tol, w_init=self.w_init,
#     442             random_state=self.random_state, return_X_mean=True,
# --> 443             compute_sources=compute_sources)
#     444
#     445         if self.whiten:
#
# /Users/lmartin/anaconda/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc in fastica(X, n_components, algorithm, whiten, fun, fun_args, max_iter, tol, w_init, random_state, return_X_mean, compute_sources)
#     312
#     313     if algorithm == 'parallel':
# --> 314         W = _ica_par(X1, **kwargs)
#     315     elif algorithm == 'deflation':
#     316         W = _ica_def(X1, **kwargs)
#
# /Users/lmartin/anaconda/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc in _ica_par(***failed resolving arguments***)
#      94     p_ = float(X.shape[1])
#      95     for ii in moves.xrange(max_iter):
# ---> 96         gwtx, g_wtx = g(np.dot(W, X), fun_args)
#      97         W1 = _sym_decorrelation(np.dot(gwtx, X.T) / p_
#      98                                 - g_wtx[:, np.newaxis] * W)
#
# /Users/lmartin/anaconda/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc in _logcosh(x, fun_args)
#     114 def _logcosh(x, fun_args=None):
#     115     alpha = fun_args.get('alpha', 1.0)  # comment it out?
# 47        -0.2411026 -0.003174289 ...
# 48        -0.2719327   0.06207144 ...
# 49         -0.224649    0.1352891 ...
# 50        -0.1527023  -0.05488719 ...
# 51        -0.1667052    0.1170455 ...
# 52         -0.213586    0.0854145 ...
# 53         -0.235592   0.06262005 ...
# 54        -0.2400283   0.03084624 ...
# 55        -0.2394758   0.07094028 ...
# 56        -0.2442007  -0.03001739 ...
# 57        -0.1730427    0.2781093 ...
# 58        -0.2708217   -0.1595875 ...
# 59        -0.2648829    0.1014601 ...
#
# [60 rows x 106 columns]

# %%
X_nonblood=dat_tp_norm[dat_tp_norm.index.get_level_values('BodySite')!='Blood']

# %%
X_nonblood
# Out:
# tax_name                     Coprobacillus  Capnocytophaga  Collinsella  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum       0.000000        0.000000     0.000000
# PR10047_27  Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.022547     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.010004     0.000000
# PR19005_39  Saliva                0.000000        0.002162     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             CordBlood_Serum       0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.000417     0.000000
# PR10032_39  Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.001103     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.001066     0.000000
# PR10025_27  Saliva                0.000000        0.003107     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.004178     0.000000
# PR10032_39c Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.001103     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.001066     0.000000
# PR10031_29c Saliva                0.000000        0.002870     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.011935     0.000000
# PR10043_30  Stool                 0.000000        0.000000     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.025195     0.000000
#             Tooth_Gum             0.000000        0.015916     0.000000
# PR10047_39c Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.006265     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.000000     0.000000
# PR19005_16  Saliva                0.000000        0.031078     0.000000
#             Stool                 0.000000        0.000000     0.009600
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.004156     0.000000
# PR10032_10  Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.007303     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.003085     0.000000
# PR10039_40  Vaginal_Swab          0.000000        0.000000     0.000000
#             Saliva                0.000000        0.001898     0.000000
#             Stool                 0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.001296     0.000000
# PR10034_25  Vaginal_Swab          0.000000        0.000000     0.000000
#             Stool                 0.000000        0.000000     0.000689
#             Saliva                0.000000        0.001703     0.000000
#             Tooth_Gum             0.000000        0.000886     0.000000
# PR10034_38c Vaginal_Swab          0.000000        0.000000     0.000000
#             Stool                 0.000000        0.000000     0.000509
#             Saliva                0.000000        0.004781     0.000000
#             Tooth_Gum             0.000000        0.001813     0.000000
# PR10031_14  Saliva                0.000000        0.001310     0.000000
#             Stool                 0.044028        0.000000     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#             Tooth_Gum             0.000000        0.003258     0.000000
# PR10046_39c Stool                 0.000000        0.000000     0.000000
#             Saliva                0.000000        0.001128     0.000000
#             Vaginal_Swab          0.000000        0.000000     0.000000
#                                        ...             ...          ...
#
# tax_name                     Cupriavidus  Granulicatella  Roseomonas  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum            0        0.000000           0
# PR10047_27  Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.001588           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.005558           0
# PR19005_39  Saliva                     0        0.018496           0
#             Vaginal_Swab               0        0.000000           0
#             CordBlood_Serum            0        0.000000           0
#             Tooth_Gum                  0        0.035431           0
# PR10032_39  Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.015760           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.002666           0
# PR10025_27  Saliva                     0        0.021527           0
#             Stool                      0        0.000000           0
#             Vaginal_Swab               0        0.000000           0
#             Tooth_Gum                  0        0.055710           0
# PR10032_39c Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.015760           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.002666           0
# PR10031_29c Saliva                     0        0.014731           0
#             Stool                      0        0.000000           0
#             Vaginal_Swab               0        0.000000           0
#             Tooth_Gum                  0        0.019530           0
# PR10043_30  Stool                      0        0.000441           0
#             Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.019765           0
#             Tooth_Gum                  0        0.025526           0
# PR10047_39c Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.017930           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.013810           0
# PR19005_16  Saliva                     0        0.011028           0
#             Stool                      0        0.000000           0
#             Vaginal_Swab               0        0.000000           0
#             Tooth_Gum                  0        0.030756           0
# PR10032_10  Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.034950           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.040435           0
# PR10039_40  Vaginal_Swab               0        0.000000           0
#             Saliva                     0        0.025300           0
#             Stool                      0        0.000000           0
#             Tooth_Gum                  0        0.025065           0
# PR10034_25  Vaginal_Swab               0        0.000000           0
#             Stool                      0        0.000000           0
#             Saliva                     0        0.021428           0
#             Tooth_Gum                  0        0.004136           0
# PR10034_38c Vaginal_Swab               0        0.000000           0
#             Stool                      0        0.000000           0
#             Saliva                     0        0.011540           0
#             Tooth_Gum                  0        0.007250           0
# PR10031_14  Saliva                     0        0.017820           0
#             Stool                      0        0.000000           0
#             Vaginal_Swab               0        0.000000           0
#             Tooth_Gum                  0        0.007120           0
# PR10046_39c Stool                      0        0.000000           0
#             Saliva                     0        0.025045           0
#             Vaginal_Swab               0        0.000000           0
#                                      ...             ...         ...
#
# tax_name                     Peptostreptococcus  Ruminococcus  Micrococcus  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum            0.000000      0.000000            0
# PR10047_27  Vaginal_Swab               0.000000      0.000000            0
#             Saliva                     0.000000      0.000000            0
#             Stool                      0.000000      0.001090            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR19005_39  Saliva                     0.000961      0.000000            0
#             Vaginal_Swab               0.000000      0.000000            0
#             CordBlood_Serum            0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10032_39  Vaginal_Swab               0.010879      0.000000            0
#             Saliva                     0.000473      0.000000            0
#             Stool                      0.000000      0.008942            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10025_27  Saliva                     0.000444      0.000000            0
#             Stool                      0.000000      0.021164            0
#             Vaginal_Swab               0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10032_39c Vaginal_Swab               0.010879      0.000000            0
#             Saliva                     0.000473      0.000000            0
#             Stool                      0.000000      0.008942            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10031_29c Saliva                     0.000000      0.000000            0
#             Stool                      0.000000      0.007809            0
#             Vaginal_Swab               0.002877      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10043_30  Stool                      0.000000      0.083407            0
#             Vaginal_Swab               0.000000      0.000000            0
#             Saliva                     0.001086      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10047_39c Vaginal_Swab               0.000000      0.000000            0
#             Saliva                     0.000216      0.000000            0
#             Stool                      0.000000      0.008878            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR19005_16  Saliva                     0.000000      0.000000            0
#             Stool                      0.000000      0.054400            0
#             Vaginal_Swab               0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10032_10  Vaginal_Swab               0.000240      0.000000            0
#             Saliva                     0.000522      0.000000            0
#             Stool                      0.000000      0.048353            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10039_40  Vaginal_Swab               0.000000      0.000136            0
#             Saliva                     0.001054      0.000000            0
#             Stool                      0.000000      0.029943            0
#             Tooth_Gum                  0.000216      0.000000            0
# PR10034_25  Vaginal_Swab               0.000000      0.000000            0
#             Stool                      0.000000      0.033548            0
#             Saliva                     0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10034_38c Vaginal_Swab               0.000000      0.000000            0
#             Stool                      0.000000      0.032553            0
#             Saliva                     0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10031_14  Saliva                     0.000786      0.000000            0
#             Stool                      0.000000      0.008097            0
#             Vaginal_Swab               0.000000      0.000000            0
#             Tooth_Gum                  0.000000      0.000000            0
# PR10046_39c Stool                      0.000000      0.001063            0
#             Saliva                     0.000451      0.000000            0
#             Vaginal_Swab               0.000000      0.000000            0
#                                             ...           ...          ...
#
# tax_name                     Staphylococcus  Streptococcus  Enterococcus  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum        0.200000       0.000000      0.000000
# PR10047_27  Vaginal_Swab           0.000325       0.000000      0.000000
#             Saliva                 0.000000       0.225151      0.000000
#             Stool                  0.000000       0.008721      0.000000
#             Tooth_Gum              0.000000       0.473138      0.000000
# PR19005_39  Saliva                 0.000000       0.212347      0.000000
#             Vaginal_Swab           0.000730       0.000000      0.000000
#             CordBlood_Serum        0.000000       0.000000      0.000000
#             Tooth_Gum              0.000000       0.722384      0.000000
# PR10032_39  Vaginal_Swab           0.000000       0.002646      0.000000
#             Saliva                 0.000000       0.373680      0.000000
#             Stool                  0.000000       0.000000      0.000000
#             Tooth_Gum              0.000000       0.528345      0.000000
# PR10025_27  Saliva                 0.000000       0.101198      0.000000
#             Stool                  0.000529       0.011640      0.000529
#             Vaginal_Swab           0.004484       0.000000      0.000000
#             Tooth_Gum              0.000000       0.385097      0.000000
# PR10032_39c Vaginal_Swab           0.000000       0.002646      0.000000
#             Saliva                 0.000000       0.373680      0.000000
#             Stool                  0.000000       0.000000      0.000000
#             Tooth_Gum              0.000000       0.528345      0.000000
# PR10031_29c Saliva                 0.000000       0.347618      0.000000
#             Stool                  0.000000       0.076711      0.000000
#             Vaginal_Swab           0.003098       0.001549      0.000000
#             Tooth_Gum              0.000723       0.718987      0.000000
# PR10043_30  Stool                  0.000000       0.004413      0.000000
#             Vaginal_Swab           0.000000       0.000000      0.000000
#             Saliva                 0.000000       0.221329      0.000000
#             Tooth_Gum              0.000000       0.434835      0.000000
# PR10047_39c Vaginal_Swab           0.004909       0.000000      0.000000
#             Saliva                 0.000000       0.214733      0.000000
#             Stool                  0.000000       0.000000      0.000000
#             Tooth_Gum              0.000000       0.190902      0.000000
# PR19005_16  Saliva                 0.000000       0.421554      0.000000
#             Stool                  0.000000       0.000000      0.000000
#             Vaginal_Swab           0.001603       0.000000      0.000000
#             Tooth_Gum              0.000000       0.525353      0.000000
# PR10032_10  Vaginal_Swab           0.000000       0.000480      0.000000
#             Saliva                 0.000000       0.417840      0.000000
#             Stool                  0.000531       0.001063      0.000000
#             Tooth_Gum              0.000000       0.670510      0.000000
# PR10039_40  Vaginal_Swab           0.000136       0.000000      0.000000
#             Saliva                 0.000000       0.357580      0.000000
#             Stool                  0.000000       0.000000      0.000000
#             Tooth_Gum              0.000000       0.707433      0.000000
# PR10034_25  Vaginal_Swab           0.001244       0.000178      0.000000
#             Stool                  0.000000       0.000689      0.000000
#             Saliva                 0.000000       0.173549      0.000000
#             Tooth_Gum              0.000000       0.693058      0.000000
# PR10034_38c Vaginal_Swab           0.000568       0.000995      0.000000
#             Stool                  0.000000       0.000509      0.000000
#             Saliva                 0.000000       0.400758      0.000000
#             Tooth_Gum              0.000000       0.692949      0.000000
# PR10031_14  Saliva                 0.000000       0.479298      0.000000
#             Stool                  0.000000       0.003036      0.000000
#             Vaginal_Swab           0.000315       0.000315      0.000000
#             Tooth_Gum              0.000241       0.586702      0.000000
# PR10046_39c Stool                  0.000425       0.001701      0.000000
#             Saliva                 0.000000       0.185018      0.000000
#             Vaginal_Swab           0.000212       0.000212      0.000000
#                                         ...            ...           ...
#
# tax_name                     Lactococcus  Catenibacterium  Sphingomonas  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum     0.000000                0             0
# PR10047_27  Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR19005_39  Saliva              0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#             CordBlood_Serum     0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10032_39  Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10025_27  Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10032_39c Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10031_29c Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10043_30  Stool               0.005737                0             0
#             Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10047_39c Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR19005_16  Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10032_10  Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10039_40  Vaginal_Swab        0.000000                0             0
#             Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10034_25  Vaginal_Swab        0.000000                0             0
#             Stool               0.000000                0             0
#             Saliva              0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10034_38c Vaginal_Swab        0.000000                0             0
#             Stool               0.000000                0             0
#             Saliva              0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10031_14  Saliva              0.000000                0             0
#             Stool               0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#             Tooth_Gum           0.000000                0             0
# PR10046_39c Stool               0.000000                0             0
#             Saliva              0.000000                0             0
#             Vaginal_Swab        0.000000                0             0
#                                      ...              ...           ...
#
# tax_name                     Aerococcus   Gemella  Atopobium  Clostridium  \
# Sample      BodySite
# PR10025_38  CordBlood_Serum    0.000000  0.000000   0.000000     0.000000
# PR10047_27  Vaginal_Swab       0.000000  0.000000   0.000000     0.000487
#             Saliva             0.000000  0.000000   0.008257     0.000000
#             Stool              0.000000  0.000000   0.000000     0.010174
#             Tooth_Gum          0.000000  0.000000   0.002964     0.000000
# PR19005_39  Saliva             0.000000  0.000000   0.012491     0.000000
#             Vaginal_Swab       0.000730  0.000000   0.000292     0.000584
#             CordBlood_Serum    0.000000  0.000000   0.000000     0.000000
#             Tooth_Gum          0.000000  0.000000   0.000625     0.000000
# PR10032_39  Vaginal_Swab       0.020582  0.002352   0.000000     0.000000
#             Saliva             0.000000  0.000000   0.004886     0.000000
#             Stool              0.000373  0.000000   0.000000     0.017884
#             Tooth_Gum          0.000000  0.000000   0.000178     0.000000
# PR10025_27  Saliva             0.000000  0.000000   0.001997     0.000000
#             Stool              0.000000  0.000000   0.000000     0.000529
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Tooth_Gum          0.000000  0.000000   0.001393     0.000000
# PR10032_39c Vaginal_Swab       0.020582  0.002352   0.000000     0.000000
#             Saliva             0.000000  0.000000   0.004886     0.000000
#             Stool              0.000373  0.000000   0.000000     0.017884
#             Tooth_Gum          0.000000  0.000000   0.000178     0.000000
# PR10031_29c Saliva             0.000000  0.000000   0.006696     0.000000
#             Stool              0.000000  0.000000   0.000000     0.002297
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Tooth_Gum          0.000000  0.000000   0.000000     0.000000
# PR10043_30  Stool              0.000000  0.000000   0.000000     0.015446
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.000381
#             Saliva             0.000000  0.000000   0.007385     0.000000
#             Tooth_Gum          0.000000  0.000000   0.000300     0.000000
# PR10047_39c Vaginal_Swab       0.000000  0.000000   0.000182     0.010364
#             Saliva             0.000000  0.000000   0.007129     0.000000
#             Stool              0.000000  0.000000   0.000000     0.002018
#             Tooth_Gum          0.000000  0.000000   0.000000     0.000000
# PR19005_16  Saliva             0.000000  0.000000   0.001003     0.000000
#             Stool              0.000000  0.000000   0.000000     0.009600
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.019238
#             Tooth_Gum          0.000000  0.000000   0.000000     0.000000
# PR10032_10  Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Saliva             0.000000  0.000000   0.003130     0.000000
#             Stool              0.000000  0.000000   0.000000     0.024973
#             Tooth_Gum          0.000000  0.000000   0.000974     0.000000
# PR10039_40  Vaginal_Swab       0.000000  0.000000   0.000136     0.000136
#             Saliva             0.000000  0.000000   0.004428     0.000000
#             Stool              0.000000  0.000000   0.000000     0.002227
#             Tooth_Gum          0.000000  0.000216   0.000000     0.000000
# PR10034_25  Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Stool              0.000000  0.000000   0.000000     0.001149
#             Saliva             0.000000  0.000000   0.003406     0.000000
#             Tooth_Gum          0.000000  0.000000   0.000000     0.000000
# PR10034_38c Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Stool              0.000000  0.000000   0.000000     0.001526
#             Saliva             0.000000  0.000165   0.004781     0.000000
#             Tooth_Gum          0.000000  0.000000   0.000000     0.000000
# PR10031_14  Saliva             0.000000  0.000524   0.004979     0.000000
#             Stool              0.000000  0.000000   0.000000     0.000506
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#             Tooth_Gum          0.000000  0.000121   0.000362     0.000000
# PR10046_39c Stool              0.000000  0.000000   0.000000     0.000000
#             Saliva             0.000000  0.000000   0.006769     0.000000
#             Vaginal_Swab       0.000000  0.000000   0.000000     0.000000
#                                     ...       ...        ...          ...
#
# tax_name                     Finegoldia
# Sample      BodySite
# PR10025_38  CordBlood_Serum    0.000000 ...
# PR10047_27  Vaginal_Swab       0.001299 ...
#             Saliva             0.000000 ...
#             Stool              0.015988 ...
#             Tooth_Gum          0.000000 ...
# PR19005_39  Saliva             0.000000 ...
#             Vaginal_Swab       0.001753 ...
#             CordBlood_Serum    0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10032_39  Vaginal_Swab       0.014996 ...
#             Saliva             0.000000 ...
#             Stool              0.014531 ...
#             Tooth_Gum          0.000000 ...
# PR10025_27  Saliva             0.000000 ...
#             Stool              0.010053 ...
#             Vaginal_Swab       0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10032_39c Vaginal_Swab       0.014996 ...
#             Saliva             0.000000 ...
#             Stool              0.014531 ...
#             Tooth_Gum          0.000000 ...
# PR10031_29c Saliva             0.000000 ...
#             Stool              0.000000 ...
#             Vaginal_Swab       0.023678 ...
#             Tooth_Gum          0.000000 ...
# PR10043_30  Stool              0.000000 ...
#             Vaginal_Swab       0.000381 ...
#             Saliva             0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10047_39c Vaginal_Swab       0.013636 ...
#             Saliva             0.000000 ...
#             Stool              0.015335 ...
#             Tooth_Gum          0.000000 ...
# PR19005_16  Saliva             0.000000 ...
#             Stool              0.000000 ...
#             Vaginal_Swab       0.001781 ...
#             Tooth_Gum          0.000000 ...
# PR10032_10  Vaginal_Swab       0.023518 ...
#             Saliva             0.000000 ...
#             Stool              0.049150 ...
#             Tooth_Gum          0.000000 ...
# PR10039_40  Vaginal_Swab       0.000682 ...
#             Saliva             0.000000 ...
#             Stool              0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10034_25  Vaginal_Swab       0.022218 ...
#             Stool              0.005285 ...
#             Saliva             0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10034_38c Vaginal_Swab       0.018332 ...
#             Stool              0.000509 ...
#             Saliva             0.000000 ...
#             Tooth_Gum          0.000000 ...
# PR10031_14  Saliva             0.000000 ...
#             Stool              0.000000 ...
#             Vaginal_Swab       0.055888 ...
#             Tooth_Gum          0.000000 ...
# PR10046_39c Stool              0.122926 ...
#             Saliva             0.000000 ...
#             Vaginal_Swab       0.000848 ...
#                                     ...
#
# [211 rows x 106 columns]

# %% [markdown]
# #### Compute mean of data pass to ICA for later use -

# %%
# Mean for body sites in DF sampled
mean_dat=pd.DataFrame()
X_nonblood=dat_tp_norm[dat_tp_norm.index.get_level_values('BodySite')!='Blood']
for bs in set(X_nonblood.index.get_level_values('BodySite')):
    bs_dat=dat_tp_norm[dat_tp_norm.index.get_level_values('BodySite')==bs]
    means=bs_dat.mean(axis=0)
    means_norm=means/means.sum()
    mean_dat[bs]=means_norm

# %% [markdown]
# #### Pre-process data for ICA -

# %%
# Blood data in DF sampled
X=dat_tp_norm[dat_tp_norm.index.get_level_values('BodySite')=='Blood']

# Normalize data by samples with zero mean 
X_norm=X.subtract(X.mean(axis=1),axis=0)

# Peek at the data
X_norm.head(3)
# Out:
# tax_name             Coprobacillus  Capnocytophaga  Collinsella  Cupriavidus  \
# Sample     BodySite
# PR10025_38 Blood         -0.009434       -0.009434    -0.009434     0.506607
# PR10047_27 Blood         -0.009434       -0.009434    -0.009434     0.144475
# PR19005_39 Blood         -0.009434       -0.009434    -0.009434    -0.009434
#
# tax_name             Granulicatella  Roseomonas  Peptostreptococcus  \
# Sample     BodySite
# PR10025_38 Blood          -0.009434   -0.009434           -0.009434
# PR10047_27 Blood          -0.009434   -0.009434           -0.009434
# PR19005_39 Blood          -0.009434   -0.009434           -0.009434
#
# tax_name             Ruminococcus  Micrococcus  Staphylococcus  Streptococcus  \
# Sample     BodySite
# PR10025_38 Blood        -0.009434    -0.009434       -0.009434      -0.009434
# PR10047_27 Blood        -0.009434     0.010498        0.000286       0.565512
# PR19005_39 Blood        -0.009434    -0.009434        0.202292       0.085287
#
# tax_name             Enterococcus  Lactococcus  Catenibacterium  Sphingomonas  \
# Sample     BodySite
# PR10025_38 Blood        -0.009434    -0.009434        -0.009434      0.054449
# PR10047_27 Blood        -0.009434    -0.009434        -0.009434     -0.009434
# PR19005_39 Blood        -0.009434     0.067113        -0.009434      0.021173
#
# tax_name             Aerococcus   Gemella  Atopobium  Clostridium  Finegoldia  \
# Sample     BodySite
# PR10025_38 Blood      -0.009434 -0.009434  -0.009434    -0.009434   -0.009434
# PR10047_27 Blood      -0.009434 -0.009434  -0.009434    -0.009434   -0.009434
# PR19005_39 Blood      -0.009434 -0.009434  -0.009434    -0.009434   -0.009434
#
# tax_name
# Sample     BodySite
# PR10025_38 Blood    ...
# PR10047_27 Blood    ...
# PR19005_39 Blood    ...
#
# [3 rows x 106 columns]

# %% [markdown]
# #### Run ICA -

# %%
from pylab import *
from numpy import *
from scipy import stats
from sklearn.decomposition import FastICA

def runICA(X,ica_comp):
    ''' Run ICA with specified number of components''' 

    # ICA
    ica = FastICA(n_components=ica_comp)
    ica.fit(X.T)
    # Write computed source data to DF
    S_est_bugs = ica.transform(X.T)
    ica_sources=pd.DataFrame()
    for i, si in enumerate(S_est_bugs.T):
        ica_sources['Source_%s'%str(i+1)]=si    
    return (ica_sources,ica)

# Compute ICA
ica_sources,ica=runICA(X_norm,7)
ica_sources.index=mean_dat.index
ica_source_coorl=ica_sources.transpose()

# %%
def computeCoorl(ica_source,df,ica_source_name):
    ''' Compute correlation with HMP or relman data '''
    
    stor=pd.DataFrame(columns=['r2'])
    for bodysite in set(df.index):
        bs=df.loc[bodysite]
        bs=pd.DataFrame(bs)
        cat=bs.merge(ica_source,left_index=True, right_index=True)
        cat.fillna(0,inplace=True)
        slope, intercept, r_value, p_value, std_err = stats.linregress(cat[ica_source_name],cat[bodysite])
        stor.loc[bodysite]=np.round(r_value**2,decimals=2)
    srt=stor.sort('r2',ascending=True)
    top_bs=srt.index[-1] 
    bs_top=pd.DataFrame(df.loc[top_bs])
    cat=bs_top.merge(ica_source,left_index=True, right_index=True, how='outer')
    cat.fillna(0,inplace=True)
    return cat,srt

for ica_source_name in ica_source_coorl.index:

    # ICA sources
    ica_source=ica_source_coorl.loc[ica_source_name]
    ica_source=np.abs(ica_source)
    ica_source=pd.DataFrame(ica_source)
    
    # Relman and HMP mean data
    mean_dat_coorl=mean_dat.transpose()
    hmp_mean_corrl=hmp_dat_norm.transpose()
    
    cat_rel,srt_rel=computeCoorl(ica_source,mean_dat_coorl,ica_source_name)
    cat_hmp,srt_hmp=computeCoorl(ica_source,hmp_mean_corrl,ica_source_name)
    
    del cat_hmp[ica_source_name]
    all_dat=cat_rel.merge(cat_hmp,left_index=True, right_index=True, how='outer')
    all_dat.fillna(0,inplace=True)
    #all_dat.sort(ica_source_name,inplace=True,ascending=False)
    
    # Trim for plotting
    all_dat=all_dat[all_dat[ica_source_name]>0]
    best_rel_site=srt_rel.index[-1]
    best_hmp_site=srt_hmp.index[-1]
    
    # r2 cutoff for plotting
    cutoff=.5
    
    plt.subplot(2,1,1)
    ind=np.arange(len(all_dat.index))
    plt.plot(ind,all_dat[ica_source_name],color='blue',alpha=0.5,label='ICA Source',drawstyle='steps') 
    if srt_rel.loc[best_rel_site,'r2'] > cutoff:
        plt.plot(ind,all_dat[best_rel_site],color='red',alpha=0.5,label='Relman Bodysite %s, $r^2$=%s'%(best_rel_site,srt_rel.loc[best_rel_site,'r2']),drawstyle='steps') 
    if srt_hmp.loc[best_hmp_site,'r2'] > cutoff:
        plt.plot(ind,all_dat[best_hmp_site],color='cyan',alpha=0.5,label='HMP Bodysite %s, $r^2$=%s'%(best_hmp_site,srt_hmp.loc[best_hmp_site,'r2']),drawstyle='steps')
    locs,labels=plt.xticks(ind,all_dat.index)
    plt.setp(labels, rotation=90, fontsize=4)
    plt.yticks(fontsize=5)
    plt.ylabel('Abundance',fontsize=6)
    plt.xlabel('Bug (ranked by abundance in ICA source signal)',fontsize=5)
    plt.xlim([-1,len(all_dat.index)])
    plt.legend(loc='upper left',fontsize=5)
    plt.tick_params(\
    axis='x',         
    which='both',      
    bottom='off',     
    top='off')    
    plt.show()
